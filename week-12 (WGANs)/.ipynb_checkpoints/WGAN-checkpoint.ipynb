# %% [markdown]
# # Wasserstein Generative Adversarial Network (WGAN)
# *This notebook was run by Arsyi Syarief Aziz (H071191003) for the Introduction to Deep Learning course (Unhas) taught by Dr. Risman Adnan.*
#
# -------
# This notebook is adapted from the UI-SRIN Introduction to GANs github repository (https://github.com/DSC-UI-SRIN/Introduction-to-GAN/blob/master/2%20-%20Wasserstein%20GANs/WGAN.ipynb).

# %% [markdown]
# ## Introduction
# In this notebook I will implement the Wassertein GAN (WGAN) algorithm to generate synthetic images that resemble images in the CIFAR10 dataset.
#
# The WGAN itself is a type of generative adversarial network that uses the 1-Wasserstein distance (opposed to the original Jensen Shannon Divergence distance) to measure the distance between a model and its target distribution. Through this change in distance metric, WGANs have been shown to be more stable than GANs during training, thus allowing them to generate better synthetic images. (https://www.depthfirstlearning.com/2019/WassersteinGAN).
#
# Below is a visualization that shows how WGANs work.
#
# ![image.png](attachment:a349fb83-5bf8-4dce-9a84-e1aaa57ec2dd.png)

# %% [markdown]
# ## 1. Importing Libraries and Configuring the Environment

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.autograd import Variable
from torchvision.utils import save_image
import numpy as np
import os

# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
ROOT = "/content/drive/My Drive/Colab Notebooks/WGANs/WGAN"
sample_dir = os.path.join(ROOT, 'sample')
# Make dir if no exist
if not os.path.exists(sample_dir):
    os.makedirs(sample_dir)

# %% [markdown]
# ## 2. Dataset

# %% [markdown]
# ### 2.1 Importing the dataset

# %%
batch_size = 100

# FashionMNIST Dataset
transform = transforms.Compose([
    transforms.ToTensor()])

train_dataset = datasets.FashionMNIST(root='./FashionMNNIST/', train=True, transform=transform, download=True)

# Data Loader (Input Pipeline)
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)

examples = enumerate(train_loader)
batch_idx, (example_data, example_targets) = next(examples)

# %%
example_data.shape
# Out:
# torch.Size([100, 1, 28, 28])

# %%
LABELS = ['T-shirt/top',
'Trouser',
'Pullover',
'Dress',
'Coat',
'Sandal',
'Shirt',
'Sneaker',
'Bag',
'Ankle boot'
]

# %% [markdown]
# ### 2.2 Previewing the dataset

# %%
## Print example
import matplotlib.pyplot as plt

fig = plt.figure()
for i in range(6):
  plt.subplot(3,2,i+1)
  plt.tight_layout()
  plt.imshow(example_data[i][0], cmap='gray', interpolation='none')
  plt.title("Ground Truth: {}".format(LABELS[example_targets[i]]))
  plt.xticks([])
  plt.yticks([])
fig

# %% [markdown]
# ## 3. Building the models

# %% [markdown]
# ### 3.1 The Generator

# %%
class Generator(nn.Module):
    def __init__(self, g_input_dim, g_output_dim):
        super(Generator, self).__init__()

        def block(in_feat, out_feat, normalize=True):
            layers = [nn.Linear(in_feat, out_feat)]
            if normalize:
                layers.append(nn.BatchNorm1d(out_feat, 0.8))
            layers.append(nn.LeakyReLU(0.2, inplace=True))
            return layers

        self.model = nn.Sequential(
            *block(g_input_dim, 128, normalize=False),
            *block(128, 256),
            *block(256, 512),
            *block(512, 1024),
            nn.Linear(1024, g_output_dim), 
            nn.Tanh())

    def forward(self, z):
        image = self.model(z)
        image = image.view(image.size(0), -1)
        return image

# %% [markdown]
# ### 3.2 The Discriminator

# %%
class Discriminator(nn.Module):
    def __init__(self, d_input_dim):
        super(Discriminator, self).__init__()

        self.model = nn.Sequential(
            nn.Linear(d_input_dim, 512),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(512, 256),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(256, 1),
            nn.Sigmoid(),
        )

    def forward(self, image):
        img_flat = image.view(image.size(0), -1)
        validity = self.model(img_flat)
        return validity

# %% [markdown]
# ## 4. Building the Network

# %%
# build network
z_dim = 100
cfar10_dim = train_dataset.data.shape[1] * train_dataset.data.shape[2] 
G = Generator(g_input_dim = z_dim, g_output_dim = cfar10_dim).to(device)
D = Discriminator(cfar10_dim).to(device)

# %%
print(G, D)
# Out:
# Generator(
#   (model): Sequential(
#     (0): Linear(in_features=100, out_features=128, bias=True)
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     (2): Linear(in_features=128, out_features=256, bias=True)
#     (3): BatchNorm1d(256, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (4): LeakyReLU(negative_slope=0.2, inplace=True)
#     (5): Linear(in_features=256, out_features=512, bias=True)
#     (6): BatchNorm1d(512, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (7): LeakyReLU(negative_slope=0.2, inplace=True)
#     (8): Linear(in_features=512, out_features=1024, bias=True)
#     (9): BatchNorm1d(1024, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (10): LeakyReLU(negative_slope=0.2, inplace=True)
#     (11): Linear(in_features=1024, out_features=784, bias=True)
#     (12): Tanh()
#   )
# ) Discriminator(
#   (model): Sequential(
#     (0): Linear(in_features=784, out_features=512, bias=True)
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     (2): Linear(in_features=512, out_features=256, bias=True)
#     (3): LeakyReLU(negative_slope=0.2, inplace=True)
#     (4): Linear(in_features=256, out_features=1, bias=True)
#     (5): Sigmoid()
#   )
# )

# %% [markdown]
# ## 5. Training the Model

# %%
# optimizer
lr = 0.00005
n_critic =  5
clip_value = 0.01
G_optimizer = torch.optim.RMSprop(params=[p for p in G.parameters() if p.requires_grad], lr=lr)
D_optimizer = torch.optim.RMSprop(params=[p for p in D.parameters() if p.requires_grad], lr=lr)

# %%
Tensor = torch.cuda.FloatTensor if torch.cuda.is_available() else torch.FloatTensor
epochs = 200
batches_done = 0
list_loss_D = []
list_loss_G = []
for epoch in range(epochs+1):

    for i, (imgs, _) in enumerate(train_loader):

        # Configure input
        real_imgs = Variable(imgs.type(Tensor))

        # ---------------------
        #  Train Discriminator
        # ---------------------

        D_optimizer.zero_grad()

        # Sample noise as generator input
        z = Variable(Tensor(np.random.normal(0, 1, (imgs.shape[0], z_dim))))

        # Generate a batch of images
        fake_imgs = G(z).detach()
        # Adversarial loss
        d_loss = -torch.mean(D(real_imgs)) + torch.mean(D(fake_imgs))

        d_loss.backward()
        D_optimizer.step()

        # Clip weights of discriminator
        for p in D.parameters():
            p.data.clamp_(-clip_value, clip_value)

        # Train the generator every n_critic iterations
        if i % n_critic == 0:

            # -----------------
            #  Train Generator
            # -----------------

            G_optimizer.zero_grad()

            # Generate a batch of images
            gen_imgs = G(z)
            # Adversarial loss
            g_loss = -torch.mean(D(gen_imgs))


            g_loss.backward()
            G_optimizer.step()

            # add loss to list
            list_loss_D.append(d_loss.item())
            list_loss_G.append(g_loss.item())
        
        if i % 300 == 0:
            print(
              "[Epoch %d/%d] [Batch %d/%d] [D loss: %f] [G loss: %f]"
              % (epoch, epochs, i, len(train_loader), d_loss.item(), g_loss.item()))

    if epoch % 5 == 0:
        save_image(gen_imgs.view(gen_imgs.size(0), 1, 28, 28), os.path.join(sample_dir, "%d.png" % epoch), nrow=5, normalize=True)

torch.save(G, os.path.join(ROOT, 'G.pt'))
torch.save(D, os.path.join(ROOT, 'D.pt'))
# Out:
# [Epoch 0/200] [Batch 0/600] [D loss: -0.010740] [G loss: -0.502761]
# [Epoch 0/200] [Batch 300/600] [D loss: -0.017057] [G loss: -0.562733]
# [Epoch 1/200] [Batch 0/600] [D loss: -0.064990] [G loss: -0.582460]
# [Epoch 1/200] [Batch 300/600] [D loss: -0.054774] [G loss: -0.469999]
# [Epoch 2/200] [Batch 0/600] [D loss: -0.096486] [G loss: -0.456582]
# [Epoch 2/200] [Batch 300/600] [D loss: -0.057163] [G loss: -0.523082]
# [Epoch 3/200] [Batch 0/600] [D loss: -0.076178] [G loss: -0.470410]
# [Epoch 3/200] [Batch 300/600] [D loss: -0.086591] [G loss: -0.488881]
# [Epoch 4/200] [Batch 0/600] [D loss: -0.062642] [G loss: -0.474097]
# [Epoch 4/200] [Batch 300/600] [D loss: -0.060227] [G loss: -0.481730]
# [Epoch 5/200] [Batch 0/600] [D loss: -0.050244] [G loss: -0.500933]
# [Epoch 5/200] [Batch 300/600] [D loss: -0.050108] [G loss: -0.474550]
# [Epoch 6/200] [Batch 0/600] [D loss: -0.044288] [G loss: -0.511101]
# [Epoch 6/200] [Batch 300/600] [D loss: -0.038012] [G loss: -0.534806]
# [Epoch 7/200] [Batch 0/600] [D loss: -0.041642] [G loss: -0.482094]
# [Epoch 7/200] [Batch 300/600] [D loss: -0.037719] [G loss: -0.527719]
# [Epoch 8/200] [Batch 0/600] [D loss: -0.043928] [G loss: -0.467116]
# [Epoch 8/200] [Batch 300/600] [D loss: -0.042390] [G loss: -0.517367]
# [Epoch 9/200] [Batch 0/600] [D loss: -0.042453] [G loss: -0.474351]
# [Epoch 9/200] [Batch 300/600] [D loss: -0.040312] [G loss: -0.505727]
# [Epoch 10/200] [Batch 0/600] [D loss: -0.040783] [G loss: -0.486456]
# [Epoch 10/200] [Batch 300/600] [D loss: -0.035060] [G loss: -0.513995]
# [Epoch 11/200] [Batch 0/600] [D loss: -0.046769] [G loss: -0.491426]
# [Epoch 11/200] [Batch 300/600] [D loss: -0.037546] [G loss: -0.493862]
# [Epoch 12/200] [Batch 0/600] [D loss: -0.040441] [G loss: -0.491612]
# [Epoch 12/200] [Batch 300/600] [D loss: -0.038638] [G loss: -0.498402]
# [Epoch 13/200] [Batch 0/600] [D loss: -0.032177] [G loss: -0.528571]
# [Epoch 13/200] [Batch 300/600] [D loss: -0.034001] [G loss: -0.497234]
# [Epoch 14/200] [Batch 0/600] [D loss: -0.041313] [G loss: -0.481392]
# [Epoch 14/200] [Batch 300/600] [D loss: -0.032267] [G loss: -0.489872]
# [Epoch 15/200] [Batch 0/600] [D loss: -0.030353] [G loss: -0.500689]
# [Epoch 15/200] [Batch 300/600] [D loss: -0.036368] [G loss: -0.545237]
# [Epoch 16/200] [Batch 0/600] [D loss: -0.035503] [G loss: -0.476409]
# [Epoch 16/200] [Batch 300/600] [D loss: -0.029002] [G loss: -0.491533]
# [Epoch 17/200] [Batch 0/600] [D loss: -0.033886] [G loss: -0.515920]
# [Epoch 17/200] [Batch 300/600] [D loss: -0.033893] [G loss: -0.520962]
# [Epoch 18/200] [Batch 0/600] [D loss: -0.030104] [G loss: -0.502717]
# [Epoch 18/200] [Batch 300/600] [D loss: -0.031006] [G loss: -0.503817]
# [Epoch 19/200] [Batch 0/600] [D loss: -0.028844] [G loss: -0.519031]
# [Epoch 19/200] [Batch 300/600] [D loss: -0.032547] [G loss: -0.464005]
# [Epoch 20/200] [Batch 0/600] [D loss: -0.029519] [G loss: -0.480437]
# [Epoch 20/200] [Batch 300/600] [D loss: -0.028495] [G loss: -0.488081]
# [Epoch 21/200] [Batch 0/600] [D loss: -0.023904] [G loss: -0.493754]
# [Epoch 21/200] [Batch 300/600] [D loss: -0.032175] [G loss: -0.517409]
# [Epoch 22/200] [Batch 0/600] [D loss: -0.026885] [G loss: -0.521000]
# [Epoch 22/200] [Batch 300/600] [D loss: -0.030532] [G loss: -0.482123]
# [Epoch 23/200] [Batch 0/600] [D loss: -0.032148] [G loss: -0.492347]
# [Epoch 23/200] [Batch 300/600] [D loss: -0.036997] [G loss: -0.503149]
# [Epoch 24/200] [Batch 0/600] [D loss: -0.028936] [G loss: -0.483801]
# [Epoch 24/200] [Batch 300/600] [D loss: -0.026779] [G loss: -0.495155]
# [Epoch 25/200] [Batch 0/600] [D loss: -0.027274] [G loss: -0.518637]
# [Epoch 25/200] [Batch 300/600] [D loss: -0.030067] [G loss: -0.506913]
# [Epoch 26/200] [Batch 0/600] [D loss: -0.027987] [G loss: -0.527075]
# [Epoch 26/200] [Batch 300/600] [D loss: -0.026248] [G loss: -0.476157]
# [Epoch 27/200] [Batch 0/600] [D loss: -0.030084] [G loss: -0.508103]
# [Epoch 27/200] [Batch 300/600] [D loss: -0.025180] [G loss: -0.468989]
# [Epoch 28/200] [Batch 0/600] [D loss: -0.026601] [G loss: -0.501028]
# [Epoch 28/200] [Batch 300/600] [D loss: -0.027733] [G loss: -0.483572]
# [Epoch 29/200] [Batch 0/600] [D loss: -0.027666] [G loss: -0.458006]
# [Epoch 29/200] [Batch 300/600] [D loss: -0.026537] [G loss: -0.498821]
# [Epoch 30/200] [Batch 0/600] [D loss: -0.024191] [G loss: -0.483927]
# [Epoch 30/200] [Batch 300/600] [D loss: -0.025189] [G loss: -0.504288]
# [Epoch 31/200] [Batch 0/600] [D loss: -0.025616] [G loss: -0.496798]
# [Epoch 31/200] [Batch 300/600] [D loss: -0.021610] [G loss: -0.496932]
# [Epoch 32/200] [Batch 0/600] [D loss: -0.022528] [G loss: -0.475239]
# [Epoch 32/200] [Batch 300/600] [D loss: -0.025328] [G loss: -0.493030]
# [Epoch 33/200] [Batch 0/600] [D loss: -0.022407] [G loss: -0.466340]
# [Epoch 33/200] [Batch 300/600] [D loss: -0.024605] [G loss: -0.498574]
# [Epoch 34/200] [Batch 0/600] [D loss: -0.020059] [G loss: -0.485914]
# [Epoch 34/200] [Batch 300/600] [D loss: -0.023164] [G loss: -0.486083]
# [Epoch 35/200] [Batch 0/600] [D loss: -0.024238] [G loss: -0.524147]
# [Epoch 35/200] [Batch 300/600] [D loss: -0.024401] [G loss: -0.526632]
# [Epoch 36/200] [Batch 0/600] [D loss: -0.021986] [G loss: -0.480069]
# [Epoch 36/200] [Batch 300/600] [D loss: -0.022224] [G loss: -0.483995]
# [Epoch 37/200] [Batch 0/600] [D loss: -0.024602] [G loss: -0.511002]
# [Epoch 37/200] [Batch 300/600] [D loss: -0.019819] [G loss: -0.493248]
# [Epoch 38/200] [Batch 0/600] [D loss: -0.022852] [G loss: -0.498441]
# [Epoch 38/200] [Batch 300/600] [D loss: -0.026157] [G loss: -0.500698]
# [Epoch 39/200] [Batch 0/600] [D loss: -0.019918] [G loss: -0.475336]
# [Epoch 39/200] [Batch 300/600] [D loss: -0.019991] [G loss: -0.494270]
# [Epoch 40/200] [Batch 0/600] [D loss: -0.018685] [G loss: -0.473043]
# [Epoch 40/200] [Batch 300/600] [D loss: -0.025781] [G loss: -0.460421]
# [Epoch 41/200] [Batch 0/600] [D loss: -0.022613] [G loss: -0.490758]
# [Epoch 41/200] [Batch 300/600] [D loss: -0.023626] [G loss: -0.473534]
# [Epoch 42/200] [Batch 0/600] [D loss: -0.022004] [G loss: -0.470927]
# [Epoch 42/200] [Batch 300/600] [D loss: -0.017810] [G loss: -0.482848]
# [Epoch 43/200] [Batch 0/600] [D loss: -0.021848] [G loss: -0.496298]
# [Epoch 43/200] [Batch 300/600] [D loss: -0.020832] [G loss: -0.500062]
# [Epoch 44/200] [Batch 0/600] [D loss: -0.021866] [G loss: -0.476158]
# [Epoch 44/200] [Batch 300/600] [D loss: -0.022521] [G loss: -0.471699]
# [Epoch 45/200] [Batch 0/600] [D loss: -0.019151] [G loss: -0.486200]
# [Epoch 45/200] [Batch 300/600] [D loss: -0.023213] [G loss: -0.504972]
# [Epoch 46/200] [Batch 0/600] [D loss: -0.022108] [G loss: -0.487058]
# [Epoch 46/200] [Batch 300/600] [D loss: -0.022902] [G loss: -0.504220]
# [Epoch 47/200] [Batch 0/600] [D loss: -0.015647] [G loss: -0.486779]
# [Epoch 47/200] [Batch 300/600] [D loss: -0.020641] [G loss: -0.472730]
# [Epoch 48/200] [Batch 0/600] [D loss: -0.020502] [G loss: -0.468077]
# [Epoch 48/200] [Batch 300/600] [D loss: -0.019740] [G loss: -0.491175]
# [Epoch 49/200] [Batch 0/600] [D loss: -0.021993] [G loss: -0.509520]
# [Epoch 49/200] [Batch 300/600] [D loss: -0.025856] [G loss: -0.485612]
# [Epoch 50/200] [Batch 0/600] [D loss: -0.020041] [G loss: -0.515328]
# [Epoch 50/200] [Batch 300/600] [D loss: -0.022426] [G loss: -0.473344]
# [Epoch 51/200] [Batch 0/600] [D loss: -0.021896] [G loss: -0.489117]
# [Epoch 51/200] [Batch 300/600] [D loss: -0.019508] [G loss: -0.491880]
# [Epoch 52/200] [Batch 0/600] [D loss: -0.018820] [G loss: -0.532836]
# [Epoch 52/200] [Batch 300/600] [D loss: -0.018685] [G loss: -0.491763]
# [Epoch 53/200] [Batch 0/600] [D loss: -0.020176] [G loss: -0.480180]
# [Epoch 53/200] [Batch 300/600] [D loss: -0.018773] [G loss: -0.464186]
# [Epoch 54/200] [Batch 0/600] [D loss: -0.017868] [G loss: -0.474873]
# [Epoch 54/200] [Batch 300/600] [D loss: -0.019649] [G loss: -0.489173]
# [Epoch 55/200] [Batch 0/600] [D loss: -0.020143] [G loss: -0.469847]
# [Epoch 55/200] [Batch 300/600] [D loss: -0.016560] [G loss: -0.497068]
# [Epoch 56/200] [Batch 0/600] [D loss: -0.021288] [G loss: -0.465043]
# [Epoch 56/200] [Batch 300/600] [D loss: -0.021446] [G loss: -0.474992]
# [Epoch 57/200] [Batch 0/600] [D loss: -0.018745] [G loss: -0.520123]
# [Epoch 57/200] [Batch 300/600] [D loss: -0.016691] [G loss: -0.490482]
# [Epoch 58/200] [Batch 0/600] [D loss: -0.015851] [G loss: -0.509184]
# [Epoch 58/200] [Batch 300/600] [D loss: -0.017885] [G loss: -0.485757]
# [Epoch 59/200] [Batch 0/600] [D loss: -0.020048] [G loss: -0.518001]
# [Epoch 59/200] [Batch 300/600] [D loss: -0.020769] [G loss: -0.481036]
# [Epoch 60/200] [Batch 0/600] [D loss: -0.019180] [G loss: -0.495259]
# [Epoch 60/200] [Batch 300/600] [D loss: -0.019300] [G loss: -0.508386]
# [Epoch 61/200] [Batch 0/600] [D loss: -0.017373] [G loss: -0.506022]
# [Epoch 61/200] [Batch 300/600] [D loss: -0.019445] [G loss: -0.509072]
# [Epoch 62/200] [Batch 0/600] [D loss: -0.018041] [G loss: -0.472700]
# [Epoch 62/200] [Batch 300/600] [D loss: -0.016376] [G loss: -0.468037]
# [Epoch 63/200] [Batch 0/600] [D loss: -0.015919] [G loss: -0.479149]
# [Epoch 63/200] [Batch 300/600] [D loss: -0.016941] [G loss: -0.483843]
# [Epoch 64/200] [Batch 0/600] [D loss: -0.016322] [G loss: -0.487020]
# [Epoch 64/200] [Batch 300/600] [D loss: -0.018208] [G loss: -0.507862]
# [Epoch 65/200] [Batch 0/600] [D loss: -0.017638] [G loss: -0.505344]
# [Epoch 65/200] [Batch 300/600] [D loss: -0.017994] [G loss: -0.505516]
# [Epoch 66/200] [Batch 0/600] [D loss: -0.020625] [G loss: -0.461406]
# [Epoch 66/200] [Batch 300/600] [D loss: -0.015984] [G loss: -0.474905]
# [Epoch 67/200] [Batch 0/600] [D loss: -0.019517] [G loss: -0.498561]
# [Epoch 67/200] [Batch 300/600] [D loss: -0.019665] [G loss: -0.508542]
# [Epoch 68/200] [Batch 0/600] [D loss: -0.014728] [G loss: -0.500522]
# [Epoch 68/200] [Batch 300/600] [D loss: -0.018734] [G loss: -0.504373]
# [Epoch 69/200] [Batch 0/600] [D loss: -0.018886] [G loss: -0.505543]
# [Epoch 69/200] [Batch 300/600] [D loss: -0.020777] [G loss: -0.518759]
# [Epoch 70/200] [Batch 0/600] [D loss: -0.018127] [G loss: -0.499102]
# [Epoch 70/200] [Batch 300/600] [D loss: -0.018550] [G loss: -0.486789]
# [Epoch 71/200] [Batch 0/600] [D loss: -0.016868] [G loss: -0.489194]
# [Epoch 71/200] [Batch 300/600] [D loss: -0.017879] [G loss: -0.502377]
# [Epoch 72/200] [Batch 0/600] [D loss: -0.016932] [G loss: -0.480839]
# [Epoch 72/200] [Batch 300/600] [D loss: -0.018019] [G loss: -0.486771]
# [Epoch 73/200] [Batch 0/600] [D loss: -0.018411] [G loss: -0.503070]
# [Epoch 73/200] [Batch 300/600] [D loss: -0.018013] [G loss: -0.501100]
# [Epoch 74/200] [Batch 0/600] [D loss: -0.017020] [G loss: -0.473965]
# [Epoch 74/200] [Batch 300/600] [D loss: -0.016901] [G loss: -0.507289]
# [Epoch 75/200] [Batch 0/600] [D loss: -0.016317] [G loss: -0.478547]
# [Epoch 75/200] [Batch 300/600] [D loss: -0.018414] [G loss: -0.469049]
# [Epoch 76/200] [Batch 0/600] [D loss: -0.017455] [G loss: -0.481372]
# [Epoch 76/200] [Batch 300/600] [D loss: -0.017728] [G loss: -0.470500]
# [Epoch 77/200] [Batch 0/600] [D loss: -0.014003] [G loss: -0.466837]
# [Epoch 77/200] [Batch 300/600] [D loss: -0.020404] [G loss: -0.440908]
# [Epoch 78/200] [Batch 0/600] [D loss: -0.016011] [G loss: -0.501455]
# [Epoch 78/200] [Batch 300/600] [D loss: -0.017140] [G loss: -0.499957]
# [Epoch 79/200] [Batch 0/600] [D loss: -0.016678] [G loss: -0.480249]
# [Epoch 79/200] [Batch 300/600] [D loss: -0.017064] [G loss: -0.501185]
# [Epoch 80/200] [Batch 0/600] [D loss: -0.018607] [G loss: -0.481832]
# [Epoch 80/200] [Batch 300/600] [D loss: -0.017421] [G loss: -0.481907]
# [Epoch 81/200] [Batch 0/600] [D loss: -0.018093] [G loss: -0.520626]
# [Epoch 81/200] [Batch 300/600] [D loss: -0.016601] [G loss: -0.499584]
# [Epoch 82/200] [Batch 0/600] [D loss: -0.014273] [G loss: -0.489953]
# [Epoch 82/200] [Batch 300/600] [D loss: -0.015538] [G loss: -0.496885]
# [Epoch 83/200] [Batch 0/600] [D loss: -0.014614] [G loss: -0.484538]
# [Epoch 83/200] [Batch 300/600] [D loss: -0.015264] [G loss: -0.486771]
# [Epoch 84/200] [Batch 0/600] [D loss: -0.015662] [G loss: -0.504925]
# [Epoch 84/200] [Batch 300/600] [D loss: -0.016704] [G loss: -0.484179]
# [Epoch 85/200] [Batch 0/600] [D loss: -0.016210] [G loss: -0.503012]
# [Epoch 85/200] [Batch 300/600] [D loss: -0.015574] [G loss: -0.505763]
# [Epoch 86/200] [Batch 0/600] [D loss: -0.016553] [G loss: -0.490235]
# [Epoch 86/200] [Batch 300/600] [D loss: -0.018438] [G loss: -0.457758]
# [Epoch 87/200] [Batch 0/600] [D loss: -0.015929] [G loss: -0.492574]
# [Epoch 87/200] [Batch 300/600] [D loss: -0.017202] [G loss: -0.491219]
# [Epoch 88/200] [Batch 0/600] [D loss: -0.014187] [G loss: -0.468750]
# [Epoch 88/200] [Batch 300/600] [D loss: -0.017626] [G loss: -0.506804]
# [Epoch 89/200] [Batch 0/600] [D loss: -0.017752] [G loss: -0.472244]
# [Epoch 89/200] [Batch 300/600] [D loss: -0.014252] [G loss: -0.504012]
# [Epoch 90/200] [Batch 0/600] [D loss: -0.016929] [G loss: -0.500962]
# [Epoch 90/200] [Batch 300/600] [D loss: -0.015723] [G loss: -0.491677]
# [Epoch 91/200] [Batch 0/600] [D loss: -0.014884] [G loss: -0.485472]
# [Epoch 91/200] [Batch 300/600] [D loss: -0.013987] [G loss: -0.522338]
# [Epoch 92/200] [Batch 0/600] [D loss: -0.016423] [G loss: -0.472495]
# [Epoch 92/200] [Batch 300/600] [D loss: -0.014578] [G loss: -0.495908]
# [Epoch 93/200] [Batch 0/600] [D loss: -0.018441] [G loss: -0.492346]
# [Epoch 93/200] [Batch 300/600] [D loss: -0.016541] [G loss: -0.478710]
# [Epoch 94/200] [Batch 0/600] [D loss: -0.015340] [G loss: -0.451701]
# [Epoch 94/200] [Batch 300/600] [D loss: -0.014361] [G loss: -0.501694]
# [Epoch 95/200] [Batch 0/600] [D loss: -0.016679] [G loss: -0.488381]
# [Epoch 95/200] [Batch 300/600] [D loss: -0.011156] [G loss: -0.507561]
# [Epoch 96/200] [Batch 0/600] [D loss: -0.015063] [G loss: -0.511704]
# [Epoch 96/200] [Batch 300/600] [D loss: -0.013909] [G loss: -0.485817]
# [Epoch 97/200] [Batch 0/600] [D loss: -0.014009] [G loss: -0.502703]
# [Epoch 97/200] [Batch 300/600] [D loss: -0.014004] [G loss: -0.480276]
# [Epoch 98/200] [Batch 0/600] [D loss: -0.015788] [G loss: -0.510153]
# [Epoch 98/200] [Batch 300/600] [D loss: -0.014196] [G loss: -0.488131]
# [Epoch 99/200] [Batch 0/600] [D loss: -0.013824] [G loss: -0.493726]
# [Epoch 99/200] [Batch 300/600] [D loss: -0.011691] [G loss: -0.497205]
# [Epoch 100/200] [Batch 0/600] [D loss: -0.014784] [G loss: -0.498879]
# [Epoch 100/200] [Batch 300/600] [D loss: -0.013591] [G loss: -0.475876]
# [Epoch 101/200] [Batch 0/600] [D loss: -0.014982] [G loss: -0.489080]
# [Epoch 101/200] [Batch 300/600] [D loss: -0.016318] [G loss: -0.507185]
# [Epoch 102/200] [Batch 0/600] [D loss: -0.015442] [G loss: -0.476580]
# [Epoch 102/200] [Batch 300/600] [D loss: -0.014754] [G loss: -0.495123]
# [Epoch 103/200] [Batch 0/600] [D loss: -0.013961] [G loss: -0.484253]
# [Epoch 103/200] [Batch 300/600] [D loss: -0.015342] [G loss: -0.495814]
# [Epoch 104/200] [Batch 0/600] [D loss: -0.017932] [G loss: -0.459957]
# [Epoch 104/200] [Batch 300/600] [D loss: -0.016773] [G loss: -0.473806]
# [Epoch 105/200] [Batch 0/600] [D loss: -0.014180] [G loss: -0.516254]
# [Epoch 105/200] [Batch 300/600] [D loss: -0.011666] [G loss: -0.507296]
# [Epoch 106/200] [Batch 0/600] [D loss: -0.015819] [G loss: -0.507606]
# [Epoch 106/200] [Batch 300/600] [D loss: -0.015565] [G loss: -0.533543]
# [Epoch 107/200] [Batch 0/600] [D loss: -0.013962] [G loss: -0.490637]
# [Epoch 107/200] [Batch 300/600] [D loss: -0.014092] [G loss: -0.514185]
# [Epoch 108/200] [Batch 0/600] [D loss: -0.011082] [G loss: -0.487325]
# [Epoch 108/200] [Batch 300/600] [D loss: -0.015274] [G loss: -0.506683]
# [Epoch 109/200] [Batch 0/600] [D loss: -0.016198] [G loss: -0.483944]
# [Epoch 109/200] [Batch 300/600] [D loss: -0.013491] [G loss: -0.509588]
# [Epoch 110/200] [Batch 0/600] [D loss: -0.014122] [G loss: -0.498958]
# [Epoch 110/200] [Batch 300/600] [D loss: -0.014215] [G loss: -0.500162]
# [Epoch 111/200] [Batch 0/600] [D loss: -0.015985] [G loss: -0.491604]
# [Epoch 111/200] [Batch 300/600] [D loss: -0.014422] [G loss: -0.500435]
# [Epoch 112/200] [Batch 0/600] [D loss: -0.014184] [G loss: -0.483600]
# [Epoch 112/200] [Batch 300/600] [D loss: -0.014252] [G loss: -0.485137]
# [Epoch 113/200] [Batch 0/600] [D loss: -0.013029] [G loss: -0.488502]
# [Epoch 113/200] [Batch 300/600] [D loss: -0.019032] [G loss: -0.487580]
# [Epoch 114/200] [Batch 0/600] [D loss: -0.010660] [G loss: -0.505027]
# [Epoch 114/200] [Batch 300/600] [D loss: -0.014682] [G loss: -0.487989]
# [Epoch 115/200] [Batch 0/600] [D loss: -0.012683] [G loss: -0.495826]
# [Epoch 115/200] [Batch 300/600] [D loss: -0.013599] [G loss: -0.484971]
# [Epoch 116/200] [Batch 0/600] [D loss: -0.016236] [G loss: -0.474333]
# [Epoch 116/200] [Batch 300/600] [D loss: -0.016331] [G loss: -0.510683]
# [Epoch 117/200] [Batch 0/600] [D loss: -0.014410] [G loss: -0.485213]
# [Epoch 117/200] [Batch 300/600] [D loss: -0.012954] [G loss: -0.478813]
# [Epoch 118/200] [Batch 0/600] [D loss: -0.014053] [G loss: -0.487741]
# [Epoch 118/200] [Batch 300/600] [D loss: -0.014827] [G loss: -0.471438]
# [Epoch 119/200] [Batch 0/600] [D loss: -0.016285] [G loss: -0.488876]
# [Epoch 119/200] [Batch 300/600] [D loss: -0.015991] [G loss: -0.473508]
# [Epoch 120/200] [Batch 0/600] [D loss: -0.014723] [G loss: -0.504758]
# [Epoch 120/200] [Batch 300/600] [D loss: -0.016304] [G loss: -0.467555]
# [Epoch 121/200] [Batch 0/600] [D loss: -0.014905] [G loss: -0.482219]
# [Epoch 121/200] [Batch 300/600] [D loss: -0.015147] [G loss: -0.516643]
# [Epoch 122/200] [Batch 0/600] [D loss: -0.013144] [G loss: -0.491784]
# [Epoch 122/200] [Batch 300/600] [D loss: -0.013229] [G loss: -0.488110]
# [Epoch 123/200] [Batch 0/600] [D loss: -0.011865] [G loss: -0.490729]
# [Epoch 123/200] [Batch 300/600] [D loss: -0.014400] [G loss: -0.506667]
# [Epoch 124/200] [Batch 0/600] [D loss: -0.009361] [G loss: -0.503905]
# [Epoch 124/200] [Batch 300/600] [D loss: -0.015476] [G loss: -0.510977]
# [Epoch 125/200] [Batch 0/600] [D loss: -0.015283] [G loss: -0.503142]
# [Epoch 125/200] [Batch 300/600] [D loss: -0.012910] [G loss: -0.493230]
# [Epoch 126/200] [Batch 0/600] [D loss: -0.011379] [G loss: -0.486341]
# [Epoch 126/200] [Batch 300/600] [D loss: -0.013399] [G loss: -0.511488]
# [Epoch 127/200] [Batch 0/600] [D loss: -0.011260] [G loss: -0.521526]
# [Epoch 127/200] [Batch 300/600] [D loss: -0.014467] [G loss: -0.476083]
# [Epoch 128/200] [Batch 0/600] [D loss: -0.012249] [G loss: -0.498889]
# [Epoch 128/200] [Batch 300/600] [D loss: -0.012751] [G loss: -0.489500]
# [Epoch 129/200] [Batch 0/600] [D loss: -0.013944] [G loss: -0.488657]
# [Epoch 129/200] [Batch 300/600] [D loss: -0.014280] [G loss: -0.516356]
# [Epoch 130/200] [Batch 0/600] [D loss: -0.013312] [G loss: -0.489010]
# [Epoch 130/200] [Batch 300/600] [D loss: -0.011655] [G loss: -0.493684]
# [Epoch 131/200] [Batch 0/600] [D loss: -0.010216] [G loss: -0.495266]
# [Epoch 131/200] [Batch 300/600] [D loss: -0.013364] [G loss: -0.498208]
# [Epoch 132/200] [Batch 0/600] [D loss: -0.011365] [G loss: -0.496292]
# [Epoch 132/200] [Batch 300/600] [D loss: -0.011072] [G loss: -0.497457]
# [Epoch 133/200] [Batch 0/600] [D loss: -0.014265] [G loss: -0.511467]
# [Epoch 133/200] [Batch 300/600] [D loss: -0.009025] [G loss: -0.499949]
# [Epoch 134/200] [Batch 0/600] [D loss: -0.013234] [G loss: -0.497946]
# [Epoch 134/200] [Batch 300/600] [D loss: -0.013139] [G loss: -0.502729]
# [Epoch 135/200] [Batch 0/600] [D loss: -0.012139] [G loss: -0.511003]
# [Epoch 135/200] [Batch 300/600] [D loss: -0.013281] [G loss: -0.492884]
# [Epoch 136/200] [Batch 0/600] [D loss: -0.014742] [G loss: -0.518428]
# [Epoch 136/200] [Batch 300/600] [D loss: -0.014646] [G loss: -0.491571]
# [Epoch 137/200] [Batch 0/600] [D loss: -0.011386] [G loss: -0.504266]
# [Epoch 137/200] [Batch 300/600] [D loss: -0.013510] [G loss: -0.512367]
# [Epoch 138/200] [Batch 0/600] [D loss: -0.012029] [G loss: -0.469417]
# [Epoch 138/200] [Batch 300/600] [D loss: -0.013529] [G loss: -0.504876]
# [Epoch 139/200] [Batch 0/600] [D loss: -0.013262] [G loss: -0.476424]
# [Epoch 139/200] [Batch 300/600] [D loss: -0.014454] [G loss: -0.467501]
# [Epoch 140/200] [Batch 0/600] [D loss: -0.014309] [G loss: -0.484923]
# [Epoch 140/200] [Batch 300/600] [D loss: -0.014527] [G loss: -0.500458]
# [Epoch 141/200] [Batch 0/600] [D loss: -0.012562] [G loss: -0.501867]
# [Epoch 141/200] [Batch 300/600] [D loss: -0.013537] [G loss: -0.503391]
# [Epoch 142/200] [Batch 0/600] [D loss: -0.013634] [G loss: -0.514080]
# [Epoch 142/200] [Batch 300/600] [D loss: -0.013333] [G loss: -0.499723]
# [Epoch 143/200] [Batch 0/600] [D loss: -0.013817] [G loss: -0.490131]
# [Epoch 143/200] [Batch 300/600] [D loss: -0.013549] [G loss: -0.476887]
# [Epoch 144/200] [Batch 0/600] [D loss: -0.015201] [G loss: -0.465156]
# [Epoch 144/200] [Batch 300/600] [D loss: -0.010391] [G loss: -0.491230]
# [Epoch 145/200] [Batch 0/600] [D loss: -0.014303] [G loss: -0.506399]
# [Epoch 145/200] [Batch 300/600] [D loss: -0.013703] [G loss: -0.509017]
# [Epoch 146/200] [Batch 0/600] [D loss: -0.016474] [G loss: -0.473562]
# [Epoch 146/200] [Batch 300/600] [D loss: -0.013399] [G loss: -0.488824]
# [Epoch 147/200] [Batch 0/600] [D loss: -0.012531] [G loss: -0.502170]
# [Epoch 147/200] [Batch 300/600] [D loss: -0.012661] [G loss: -0.502124]
# [Epoch 148/200] [Batch 0/600] [D loss: -0.010780] [G loss: -0.500307]
# [Epoch 148/200] [Batch 300/600] [D loss: -0.014335] [G loss: -0.500752]
# [Epoch 149/200] [Batch 0/600] [D loss: -0.015426] [G loss: -0.513777]
# [Epoch 149/200] [Batch 300/600] [D loss: -0.012467] [G loss: -0.507552]
# [Epoch 150/200] [Batch 0/600] [D loss: -0.016824] [G loss: -0.540438]
# [Epoch 150/200] [Batch 300/600] [D loss: -0.013545] [G loss: -0.490355]
# [Epoch 151/200] [Batch 0/600] [D loss: -0.012088] [G loss: -0.482287]
# [Epoch 151/200] [Batch 300/600] [D loss: -0.016214] [G loss: -0.513669]
# [Epoch 152/200] [Batch 0/600] [D loss: -0.011694] [G loss: -0.520016]
# [Epoch 152/200] [Batch 300/600] [D loss: -0.013625] [G loss: -0.506573]
# [Epoch 153/200] [Batch 0/600] [D loss: -0.014415] [G loss: -0.495952]
# [Epoch 153/200] [Batch 300/600] [D loss: -0.014827] [G loss: -0.468428]
# [Epoch 154/200] [Batch 0/600] [D loss: -0.014947] [G loss: -0.486468]
# [Epoch 154/200] [Batch 300/600] [D loss: -0.012500] [G loss: -0.486054]
# [Epoch 155/200] [Batch 0/600] [D loss: -0.011710] [G loss: -0.486123]
# [Epoch 155/200] [Batch 300/600] [D loss: -0.011364] [G loss: -0.487868]
# [Epoch 156/200] [Batch 0/600] [D loss: -0.012772] [G loss: -0.493150]
# [Epoch 156/200] [Batch 300/600] [D loss: -0.010489] [G loss: -0.497076]
# [Epoch 157/200] [Batch 0/600] [D loss: -0.013321] [G loss: -0.492047]
# [Epoch 157/200] [Batch 300/600] [D loss: -0.013930] [G loss: -0.498094]
# [Epoch 158/200] [Batch 0/600] [D loss: -0.011924] [G loss: -0.488598]
# [Epoch 158/200] [Batch 300/600] [D loss: -0.010862] [G loss: -0.488599]
# [Epoch 159/200] [Batch 0/600] [D loss: -0.012385] [G loss: -0.498273]
# [Epoch 159/200] [Batch 300/600] [D loss: -0.012727] [G loss: -0.478613]
# [Epoch 160/200] [Batch 0/600] [D loss: -0.012485] [G loss: -0.485983]
# [Epoch 160/200] [Batch 300/600] [D loss: -0.012907] [G loss: -0.469261]
# [Epoch 161/200] [Batch 0/600] [D loss: -0.012562] [G loss: -0.486285]
# [Epoch 161/200] [Batch 300/600] [D loss: -0.012454] [G loss: -0.498391]
# [Epoch 162/200] [Batch 0/600] [D loss: -0.011502] [G loss: -0.496293]
# [Epoch 162/200] [Batch 300/600] [D loss: -0.012883] [G loss: -0.482664]
# [Epoch 163/200] [Batch 0/600] [D loss: -0.011936] [G loss: -0.482836]
# [Epoch 163/200] [Batch 300/600] [D loss: -0.013906] [G loss: -0.492960]
# [Epoch 164/200] [Batch 0/600] [D loss: -0.012607] [G loss: -0.508635]
# [Epoch 164/200] [Batch 300/600] [D loss: -0.013072] [G loss: -0.472197]
# [Epoch 165/200] [Batch 0/600] [D loss: -0.009593] [G loss: -0.479164]
# [Epoch 165/200] [Batch 300/600] [D loss: -0.011129] [G loss: -0.486515]
# [Epoch 166/200] [Batch 0/600] [D loss: -0.014158] [G loss: -0.488628]
# [Epoch 166/200] [Batch 300/600] [D loss: -0.011994] [G loss: -0.489291]
# [Epoch 167/200] [Batch 0/600] [D loss: -0.011138] [G loss: -0.513200]
# [Epoch 167/200] [Batch 300/600] [D loss: -0.009875] [G loss: -0.519088]
# [Epoch 168/200] [Batch 0/600] [D loss: -0.013217] [G loss: -0.514689]
# [Epoch 168/200] [Batch 300/600] [D loss: -0.011717] [G loss: -0.484447]
# [Epoch 169/200] [Batch 0/600] [D loss: -0.010545] [G loss: -0.493894]
# [Epoch 169/200] [Batch 300/600] [D loss: -0.010919] [G loss: -0.524301]
# [Epoch 170/200] [Batch 0/600] [D loss: -0.013729] [G loss: -0.483232]
# [Epoch 170/200] [Batch 300/600] [D loss: -0.012428] [G loss: -0.491822]
# [Epoch 171/200] [Batch 0/600] [D loss: -0.012266] [G loss: -0.503708]
# [Epoch 171/200] [Batch 300/600] [D loss: -0.012918] [G loss: -0.507925]
# [Epoch 172/200] [Batch 0/600] [D loss: -0.007263] [G loss: -0.494453]
# [Epoch 172/200] [Batch 300/600] [D loss: -0.008696] [G loss: -0.497903]
# [Epoch 173/200] [Batch 0/600] [D loss: -0.011298] [G loss: -0.501818]
# [Epoch 173/200] [Batch 300/600] [D loss: -0.011918] [G loss: -0.522947]
# [Epoch 174/200] [Batch 0/600] [D loss: -0.011946] [G loss: -0.501662]
# [Epoch 174/200] [Batch 300/600] [D loss: -0.011877] [G loss: -0.485889]
# [Epoch 175/200] [Batch 0/600] [D loss: -0.014991] [G loss: -0.465889]
# [Epoch 175/200] [Batch 300/600] [D loss: -0.011552] [G loss: -0.486262]
# [Epoch 176/200] [Batch 0/600] [D loss: -0.014762] [G loss: -0.529169]
# [Epoch 176/200] [Batch 300/600] [D loss: -0.013049] [G loss: -0.491983]
# [Epoch 177/200] [Batch 0/600] [D loss: -0.013075] [G loss: -0.485231]
# [Epoch 177/200] [Batch 300/600] [D loss: -0.013589] [G loss: -0.504478]
# [Epoch 178/200] [Batch 0/600] [D loss: -0.011848] [G loss: -0.493181]
# [Epoch 178/200] [Batch 300/600] [D loss: -0.012859] [G loss: -0.499443]
# [Epoch 179/200] [Batch 0/600] [D loss: -0.011427] [G loss: -0.485769]
# [Epoch 179/200] [Batch 300/600] [D loss: -0.010107] [G loss: -0.519833]
# [Epoch 180/200] [Batch 0/600] [D loss: -0.012566] [G loss: -0.493157]
# [Epoch 180/200] [Batch 300/600] [D loss: -0.011395] [G loss: -0.482620]
# [Epoch 181/200] [Batch 0/600] [D loss: -0.010310] [G loss: -0.511397]
# [Epoch 181/200] [Batch 300/600] [D loss: -0.011686] [G loss: -0.499097]
# [Epoch 182/200] [Batch 0/600] [D loss: -0.010234] [G loss: -0.501527]
# [Epoch 182/200] [Batch 300/600] [D loss: -0.011738] [G loss: -0.486260]
# [Epoch 183/200] [Batch 0/600] [D loss: -0.011936] [G loss: -0.501719]
# [Epoch 183/200] [Batch 300/600] [D loss: -0.013192] [G loss: -0.490774]
# [Epoch 184/200] [Batch 0/600] [D loss: -0.011296] [G loss: -0.479874]
# [Epoch 184/200] [Batch 300/600] [D loss: -0.009723] [G loss: -0.484899]
# [Epoch 185/200] [Batch 0/600] [D loss: -0.011683] [G loss: -0.510979]
# [Epoch 185/200] [Batch 300/600] [D loss: -0.012362] [G loss: -0.500852]
# [Epoch 186/200] [Batch 0/600] [D loss: -0.012515] [G loss: -0.472419]
# [Epoch 186/200] [Batch 300/600] [D loss: -0.011743] [G loss: -0.462976]
# [Epoch 187/200] [Batch 0/600] [D loss: -0.010744] [G loss: -0.489006]
# [Epoch 187/200] [Batch 300/600] [D loss: -0.010687] [G loss: -0.518279]
# [Epoch 188/200] [Batch 0/600] [D loss: -0.012612] [G loss: -0.481251]
# [Epoch 188/200] [Batch 300/600] [D loss: -0.011268] [G loss: -0.493682]
# [Epoch 189/200] [Batch 0/600] [D loss: -0.012764] [G loss: -0.472920]
# [Epoch 189/200] [Batch 300/600] [D loss: -0.009913] [G loss: -0.499714]
# [Epoch 190/200] [Batch 0/600] [D loss: -0.011862] [G loss: -0.510670]
# [Epoch 190/200] [Batch 300/600] [D loss: -0.011570] [G loss: -0.490981]
# [Epoch 191/200] [Batch 0/600] [D loss: -0.010223] [G loss: -0.502727]
# [Epoch 191/200] [Batch 300/600] [D loss: -0.008744] [G loss: -0.489810]
# [Epoch 192/200] [Batch 0/600] [D loss: -0.011146] [G loss: -0.455947]
# [Epoch 192/200] [Batch 300/600] [D loss: -0.011672] [G loss: -0.497813]
# [Epoch 193/200] [Batch 0/600] [D loss: -0.011834] [G loss: -0.497851]
# [Epoch 193/200] [Batch 300/600] [D loss: -0.013175] [G loss: -0.477793]
# [Epoch 194/200] [Batch 0/600] [D loss: -0.013133] [G loss: -0.492162]
# [Epoch 194/200] [Batch 300/600] [D loss: -0.014047] [G loss: -0.502850]
# [Epoch 195/200] [Batch 0/600] [D loss: -0.011229] [G loss: -0.481204]
# [Epoch 195/200] [Batch 300/600] [D loss: -0.011146] [G loss: -0.503012]
# [Epoch 196/200] [Batch 0/600] [D loss: -0.010628] [G loss: -0.493160]
# [Epoch 196/200] [Batch 300/600] [D loss: -0.010848] [G loss: -0.483689]
# [Epoch 197/200] [Batch 0/600] [D loss: -0.010194] [G loss: -0.485902]
# [Epoch 197/200] [Batch 300/600] [D loss: -0.011812] [G loss: -0.494298]
# [Epoch 198/200] [Batch 0/600] [D loss: -0.012865] [G loss: -0.477229]
# [Epoch 198/200] [Batch 300/600] [D loss: -0.009948] [G loss: -0.511688]
# [Epoch 199/200] [Batch 0/600] [D loss: -0.009676] [G loss: -0.478953]
# [Epoch 199/200] [Batch 300/600] [D loss: -0.013586] [G loss: -0.477169]
# [Epoch 200/200] [Batch 0/600] [D loss: -0.010340] [G loss: -0.483072]
# [Epoch 200/200] [Batch 300/600] [D loss: -0.010437] [G loss: -0.496807]

# %% [markdown]
# ## 6. Viewing the results

# %%
Tensor = torch.cuda.FloatTensor if torch.cuda.is_available() else torch.FloatTensor
z = Variable(Tensor(np.random.normal(0, 1, (15, z_dim))))
gen_imgs = G(z).detach()
fig = plt.figure()
for i in range(15):
    plt.subplot(5,3,i+1)
    plt.tight_layout()
    plt.imshow(gen_imgs[i].cpu().view(28, 28), cmap='gray', interpolation='none')
    plt.xticks([])
    plt.yticks([])
